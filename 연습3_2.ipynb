# %% [markdown]
# <a href="https://colab.research.google.com/github/opmaksim/Colab_opencv/blob/main/%EC%97%B0%EC%8A%B53_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/gdrive')
#영상 불러오기
img1 = cv2.imread('/content/gdrive/My Drive/Image_Processing/aero2.bmp')
img2 = cv2.imread('/content/gdrive/My Drive/Image_Processing/milkdrop.bmp')
img_plus = img1+img2
img_add=cv2.add(img1,img2)

#그림을 화면에 출력
plt.figure(figsize=(20,20))# 영상의 크기를 키워주자
plt.subplot(1,2,1)# 1행 4열에서 1번째 열 plt.title("First image")
plt.title("Plus image")
plt.imshow(img_plus)
plt.axis("off")
plt.subplot(1,2,2)# 1행 4열에서 1번째 열 plt.title("First image")
plt.title("Saturation")
plt.imshow(img_add)
plt.axis("off")
plt.show()
# Out:
# Mounted at /content/gdrive
