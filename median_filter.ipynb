# %% [markdown]
# <a href="https://colab.research.google.com/github/opmaksim/Colab_opencv/blob/main/median_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/gdrive')
#영상 불러오기
img = cv2.imread('/content/gdrive/My Drive/Image_Processing/Lena-Gaussian-noise1.jpg')

# color영상을 gray영상으로 만들기
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
rows = gray_img.shape[0]
cols = gray_img.shape[1]
output_img = np.zeros((rows, cols), dtype=np.uint8)

kernel_radius = 1

for i in range(kernel_radius, rows - kernel_radius):
    for j in range(kernel_radius, cols - kernel_radius):
        # 5x5 이웃 픽셀들 가져오기
        neighbors = []
        for k in range(-kernel_radius, kernel_radius + 1):
            for l in range(-kernel_radius, kernel_radius + 1):
                neighbors.append(gray_img[i + k, j + l])

        # 중간값 계산
        median_value = np.median(neighbors)

        # 중간값으로 픽셀 값을 설정
        output_img[i, j] = median_value


#그림을 화면에 출력
plt.figure(figsize=(20,20))# 영상의 크기를 키워주자
plt.subplot(1,2,1)
plt.title("Image1")
plt.imshow(gray_img, cmap='gray')
plt.axis("off")
plt.subplot(1,2,2)
plt.title("Median filtering Image")
plt.imshow(output_img, cmap='gray')
plt.axis("off")
plt.show()
for i in range (30):
  pixel_value = output_img[i, i]
  print(f"Pixel value: {pixel_value}")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Pixel value: 0
# Pixel value: 141
# Pixel value: 135
# Pixel value: 135
# Pixel value: 135
# Pixel value: 135
# Pixel value: 131
# Pixel value: 133
# Pixel value: 128
# Pixel value: 125
# Pixel value: 129
# Pixel value: 130
# Pixel value: 130
# Pixel value: 127
# Pixel value: 136
# Pixel value: 125
# Pixel value: 131
# Pixel value: 125
# Pixel value: 127
# Pixel value: 127
# Pixel value: 134
# Pixel value: 130
# Pixel value: 132
# Pixel value: 130
# Pixel value: 128
# Pixel value: 128
# Pixel value: 128
# Pixel value: 131
# Pixel value: 140
# Pixel value: 143
